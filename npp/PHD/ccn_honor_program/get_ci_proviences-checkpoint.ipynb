# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
df=pd.read_csv("cities_with_country.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     AREA  PERIMETER  LEVEL1_  LEVEL1_ID  AD2004 NAME2004  \
# 0           0  54.4821    70.1328        1          1  230000     黑龙江省
# 1           0  54.4821    70.1328        1          1  230000     黑龙江省
# 2           0  54.4821    70.1328        1          1  230000     黑龙江省
# 3           0  54.4821    70.1328        1          1  230000     黑龙江省
# 4           0  54.4821    70.1328        1          1  230000     黑龙江省
#
#                                             geometry  index_right   DATE  \
# 0  POLYGON ((132.8446807861328 45.06007385253906,...        22682  1983Y
# 1  POLYGON ((132.8446807861328 45.06007385253906,...        30998  1993Y
# 2  POLYGON ((132.8446807861328 45.06007385253906,...        23431  1984Y
# 3  POLYGON ((132.8446807861328 45.06007385253906,...        29345  1991Y
# 4  POLYGON ((132.8446807861328 45.06007385253906,...        26901  1988Y
#
#       Stid  Height     Lat      Lon        ci
# 0  50247.0  5208.0  5203.0  12340.0  0.595851
# ...

# %%
df=df.drop(["geometry"],axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0     AREA  PERIMETER  LEVEL1_  LEVEL1_ID  AD2004 NAME2004  \
# 0           0  54.4821    70.1328        1          1  230000     黑龙江省
# 1           0  54.4821    70.1328        1          1  230000     黑龙江省
# 2           0  54.4821    70.1328        1          1  230000     黑龙江省
# 3           0  54.4821    70.1328        1          1  230000     黑龙江省
# 4           0  54.4821    70.1328        1          1  230000     黑龙江省
#
#    index_right   DATE     Stid  Height     Lat      Lon        ci
# 0        22682  1983Y  50247.0  5208.0  5203.0  12340.0  0.595851
# 1        30998  1993Y  50247.0  5208.0  5203.0  12340.0  0.646257
# 2        23431  1984Y  50247.0  5208.0  5203.0  12340.0  0.666604
# 3        29345  1991Y  50247.0  5208.0  5203.0  12340.0  0.699479
# 4        26901  1988Y  50247.0  5208.0  5203.0  12340.0  0.651139

# %%
df.drop(["Unnamed: 0"],axis=1)
# Out:
#             AREA  PERIMETER  LEVEL1_  LEVEL1_ID  AD2004 NAME2004  index_right  \
# 0      54.482100   70.13280        1          1  230000     黑龙江省        22682
# 1      54.482100   70.13280        1          1  230000     黑龙江省        30998
# 2      54.482100   70.13280        1          1  230000     黑龙江省        23431
# 3      54.482100   70.13280        1          1  230000     黑龙江省        29345
# 4      54.482100   70.13280        1          1  230000     黑龙江省        26901
# 5      54.482100   70.13280        1          1  230000     黑龙江省        25956
# 6      54.482100   70.13280        1          1  230000     黑龙江省        19412
# 7      54.482100   70.13280        1          1  230000     黑龙江省        30218
# 8      54.482100   70.13280        1          1  230000     黑龙江省        27610
# 9      54.482100   70.13280        1          1  230000     黑龙江省        32000
# 10     54.482100   70.13280        1          1  230000     黑龙江省        18472
# ...

# %%
df.to_csv("ci_all.csv",index=False)

# %%
df=df.sort_values(by=["DATE","NAME2004"],ascending=[True,False])

# %%
df.head()
# Out:
#        Unnamed: 0     AREA  PERIMETER  LEVEL1_  LEVEL1_ID  AD2004 NAME2004  \
# 499             0  54.4821    70.1328        1          1  230000     黑龙江省
# 937             0  54.4821    70.1328        1          1  230000     黑龙江省
# 1732            0  54.4821    70.1328        1          1  230000     黑龙江省
# 2034            0  54.4821    70.1328        1          1  230000     黑龙江省
# 35650          21   7.7115    27.1712       22         22  500000      重庆市
#
#        index_right   DATE     Stid  Height     Lat      Lon        ci
# 499             47  1951Y  50557.0  2223.0  4910.0  12513.0  0.609287
# 937             18  1951Y  50745.0  1470.0  4720.0  12356.0  0.586489
# 1732             8  1951Y  50953.0  1451.0  4545.0  12638.0  0.642825
# 2034            44  1951Y  54094.0  2403.0  4435.0  12936.0  0.613729
# 35650           49  1951Y  57516.0  2910.0  2930.0  10633.0  0.677529

# %%
df=df.drop(["Unnamed: 0"],axis=1)

# %%
df.head()
# Out:
#           AREA  PERIMETER  LEVEL1_  LEVEL1_ID  AD2004 NAME2004  index_right  \
# 499    54.4821    70.1328        1          1  230000     黑龙江省           47
# 937    54.4821    70.1328        1          1  230000     黑龙江省           18
# 1732   54.4821    70.1328        1          1  230000     黑龙江省            8
# 2034   54.4821    70.1328        1          1  230000     黑龙江省           44
# 35650   7.7115    27.1712       22         22  500000      重庆市           49
#
#         DATE     Stid  Height     Lat      Lon        ci
# 499    1951Y  50557.0  2223.0  4910.0  12513.0  0.609287
# 937    1951Y  50745.0  1470.0  4720.0  12356.0  0.586489
# 1732   1951Y  50953.0  1451.0  4545.0  12638.0  0.642825
# 2034   1951Y  54094.0  2403.0  4435.0  12936.0  0.613729
# 35650  1951Y  57516.0  2910.0  2930.0  10633.0  0.677529

# %%
df.to_csv("ci_all.csv",index=False)
