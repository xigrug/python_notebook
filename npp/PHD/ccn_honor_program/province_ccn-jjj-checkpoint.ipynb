# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib import cm as CM
from matplotlib.colors import LogNorm,PowerNorm
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.io.shapereader import Reader
import matplotlib.ticker as mticker
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from shapely.geometry import *
from scipy.interpolate import griddata
import cmocean

# %%
fp = "D:/data/map/JingJinJi.shp" #生成的坐标不对
mapfile = gpd.read_file(fp,encoding='gbk')

# %%
mapfile

# %%
data = pd.read_csv('avg_0.5_CCN.csv', sep=',',skiprows=0,header=0)

# %%
data

# %%
data['Coordinates'] = list(zip(data.lon, data.lat))
data['Coordinates'] = data['Coordinates'].apply(Point)

# %%
# get geo data
gdf = gpd.GeoDataFrame(data, geometry='Coordinates')
gdf.crs = mapfile.crs
#gdf=gdf.dropna(subset=[ '2001'])#Remember to reassign
cities_with_country = gpd.sjoin(mapfile,gdf,how="inner", op='intersects')
#print(df1)
#df1.to_csv("cities_with_country.csv")

# %%
gdf
# Out:
#                         BJC  AMR_lowest  AMR_surf  AOD  B4LI    CAPE  \
# 0       2013-06-01 05:09:00         NaN       NaN  NaN -5.20  2176.0
# 1       2013-06-01 05:09:00         NaN       NaN  NaN -5.20  2176.0
# 2       2013-06-01 05:09:00         NaN       NaN  NaN -5.20  2176.0
# 3       2013-06-01 05:09:00         NaN       NaN  NaN -5.30  2149.0
# 4       2013-06-01 05:09:00         NaN       NaN  NaN -5.30  2149.0
# 5       2013-06-01 05:09:00         NaN       NaN  NaN -6.90  2822.0
# 6       2013-06-01 05:09:00         NaN       NaN  NaN -6.90  2822.0
# 7       2013-06-01 05:09:00         NaN       NaN  NaN -6.00  2678.0
# 8       2013-06-01 05:09:00         NaN       NaN  NaN -6.00  2678.0
# 9       2013-06-01 05:09:00         NaN       NaN  NaN -6.10  2574.0
# 10      2013-06-01 05:09:00         NaN       NaN  NaN -6.10  2574.0
# 11      2013-06-01 05:09:00         NaN       NaN  NaN -5.30  1902.0
# 12      2013-06-01 05:09:00         NaN       NaN  NaN -5.30  1902.0
# 13      2013-06-01 05:09:00         NaN       NaN  NaN -6.00  2678.0
# 14      2013-06-01 05:09:00         NaN       NaN  NaN -6.10  2574.0
# 15      2013-06-01 05:09:00         NaN       NaN  NaN -5.30  1902.0
# 16      2013-06-01 05:09:00         NaN       NaN  NaN -5.30  1902.0
# 17      2013-06-01 05:09:00         NaN       NaN  NaN -3.20   812.0
# 18      2013-06-01 05:09:00         NaN       NaN  NaN -3.60  1119.0
# 19      2013-06-01 05:09:00         NaN       NaN  NaN -4.80  1986.0
# 20      2013-06-01 05:09:00         NaN       NaN  NaN -4.70  2219.0
# 21      2013-06-01 05:09:00         NaN       NaN  NaN -4.70  2219.0
# 22      2013-06-01 05:09:00         NaN       NaN  NaN -4.60  2112.0
# 23      2013-06-01 05:09:00         NaN       NaN  NaN -4.30  1634.0
# 24      2013-06-01 05:09:00         NaN       NaN  NaN -4.30  1634.0
# 25      2013-06-01 05:09:00         NaN       NaN  NaN -3.00   620.0
# 26      2013-06-01 05:09:00         NaN       NaN  NaN -2.80   559.0
# 27      2013-06-01 05:09:00         NaN       NaN  NaN -4.80  1986.0
# 28      2013-06-01 05:09:00         NaN       NaN  NaN -4.70  2219.0
# 29      2013-06-01 05:09:00         NaN       NaN  NaN -4.70  2219.0
# ...                     ...         ...       ...  ...   ...     ...
# 118452  2019-08-31 05:23:00         NaN       NaN  NaN -1.96   530.0
# 118453  2019-08-31 05:23:00         NaN       NaN  NaN -1.76   480.0
# 118454  2019-08-31 05:23:00         NaN       NaN  NaN -1.66   400.0
# 118455  2019-08-31 05:23:00         NaN       NaN  NaN -1.21   356.0
# 118456  2019-08-31 05:23:00         NaN       NaN  NaN -0.56   247.0
# 118457  2019-08-31 05:23:00         NaN       NaN  NaN -0.86   207.0
# 118458  2019-08-31 05:23:00         NaN       NaN  NaN -2.66   641.0
# 118459  2019-08-31 05:23:00         NaN       NaN  NaN -2.66   724.0
# 118460  2019-08-31 05:23:00         NaN       NaN  NaN -2.36   600.0
# 118461  2019-08-31 05:23:00         NaN       NaN  NaN -2.21   472.0
# 118462  2019-08-31 05:23:00         NaN       NaN  NaN -1.91   370.5
# 118463  2019-08-31 05:23:00         NaN       NaN  NaN -1.86   338.0
# 118464  2019-08-31 05:23:00         NaN       NaN  NaN -1.96   408.0
# 118465  2019-08-31 05:23:00         NaN       NaN  NaN -1.31   290.5
# 118466  2019-08-31 05:23:00         NaN       NaN  NaN -1.76   393.0
# 118467  2019-08-31 05:23:00         NaN       NaN  NaN -1.16   363.0
# 118468  2019-08-31 05:23:00         NaN       NaN  NaN -0.96   327.0
# 118469  2019-08-31 05:23:00         NaN       NaN  NaN -0.66   234.0
# 118470  2019-08-31 05:23:00         NaN       NaN  NaN -1.36   203.0
# 118471  2019-08-31 05:23:00         NaN       NaN  NaN -3.36   838.0
# 118472  2019-08-31 05:23:00         NaN       NaN  NaN -2.96   924.0
# 118473  2019-08-31 05:23:00         NaN       NaN  NaN -2.66   620.0
# 118474  2019-08-31 05:23:00         NaN       NaN  NaN -1.86   393.0
# 118475  2019-08-31 05:23:00         NaN       NaN  NaN -2.06   685.5
# 118476  2019-08-31 05:23:00         NaN       NaN  NaN -2.21   571.5
# 118477  2019-08-31 05:23:00         NaN       NaN  NaN -1.96   547.0
# 118478  2019-08-31 05:23:00         NaN       NaN  NaN -2.56   746.0
# 118479  2019-08-31 05:23:00         NaN       NaN  NaN -2.66   827.0
# 118480  2019-08-31 05:23:00         NaN       NaN  NaN -2.86   863.0
# 118481  2019-08-31 05:23:00         NaN       NaN  NaN -2.76   806.0
#
#         CAPE_lowest      CAPE_nc  CAPE_surf  CCN_0.5_cm3  ...    satz    solz  \
# 0               NaN  2098.500000        NaN       1280.0  ... -16.495  14.370
# 1               NaN  2076.000000        NaN       1059.0  ... -17.960  14.200
# 2               NaN  2121.000000        NaN       1069.0  ... -15.020  14.560
# 3               NaN  2121.000000        NaN        704.0  ... -12.100  14.905
# 4               NaN  2048.666667        NaN        866.0  ...  -8.220  15.370
# 5               NaN  1904.000000        NaN       1252.0  ...  -4.830  15.755
# 6               NaN  1904.000000        NaN       1337.0  ...  -0.480  16.260
# 7               NaN  2329.500000        NaN       1247.0  ... -17.960  14.235
# 8               NaN  2329.500000        NaN       1002.5  ... -15.030  14.595
# 9               NaN  2121.000000        NaN        921.0  ... -12.100  14.930
# 10              NaN  2012.500000        NaN       1406.0  ...  -7.735  15.450
# 11              NaN  1904.000000        NaN       1216.0  ...  -3.375  15.940
# 12              NaN  1904.000000        NaN       1338.5  ...  -0.475  16.280
# 13              NaN  2583.000000        NaN       3817.0  ... -17.960  14.320
# 14              NaN  1904.000000        NaN       1021.0  ...  -6.280  15.655
# 15              NaN  1904.000000        NaN       1252.0  ...  -3.380  15.995
# 16              NaN  1904.000000        NaN       3600.0  ...  -0.480  16.310
# 17              NaN   941.000000        NaN        688.0  ...  28.890  19.910
# 18              NaN   667.000000        NaN         94.0  ...  48.060  23.200
# 19              NaN  1840.000000        NaN       1574.0  ... -17.960  14.370
# 20              NaN  2323.000000        NaN       1219.0  ... -15.030  14.700
# 21              NaN  2323.000000        NaN       2971.0  ... -12.100  15.050
# 22              NaN  2108.000000        NaN       6105.0  ...  -9.190  15.420
# 23              NaN  1904.000000        NaN       1499.5  ...  -0.480  16.355
# 24              NaN  1631.000000        NaN       1247.0  ...   2.470  16.690
# 25              NaN   557.000000        NaN       2455.0  ...  28.890  19.930
# 26              NaN   749.000000        NaN        605.5  ...  31.900  20.360
# 27              NaN  1840.000000        NaN        992.5  ... -17.960  14.450
# 28              NaN  2108.000000        NaN       1324.0  ... -15.030  14.810
# 29              NaN  2108.000000        NaN        626.0  ... -12.100  15.120
# ...             ...          ...        ...          ...  ...     ...     ...
# 118452          NaN   310.000000        NaN        208.0  ...  39.560  43.000
# 118453          NaN   310.000000        NaN        290.0  ...  41.650  43.220
# 118454          NaN   323.000000        NaN        397.0  ...  43.760  43.450
# 118455          NaN   323.000000        NaN        271.0  ...  45.900  43.830
# 118456          NaN   323.000000        NaN        242.0  ...  48.060  43.980
# 118457          NaN   196.000000        NaN        379.0  ...  -3.390  41.280
# 118458          NaN   196.000000        NaN        470.0  ...  -0.490  41.440
# 118459          NaN   576.000000        NaN        405.0  ...   2.460  41.610
# 118460          NaN   576.000000        NaN        494.0  ...   5.350  41.780
# 118461          NaN   576.000000        NaN        471.0  ...   8.260  41.815
# 118462          NaN   752.000000        NaN        487.5  ...  11.170  41.995
# 118463          NaN   752.000000        NaN        293.0  ...  14.100  42.040
# 118464          NaN   321.000000        NaN        558.0  ...  22.920  42.640
# 118465          NaN   321.000000        NaN        964.5  ...  25.895  42.720
# 118466          NaN   667.000000        NaN        782.0  ...  28.890  42.820
# 118467          NaN   310.000000        NaN        369.0  ...  37.500  43.310
# 118468          NaN   310.000000        NaN        379.0  ...  39.570  43.510
# 118469          NaN   323.000000        NaN        291.0  ...  48.060  44.230
# 118470          NaN   752.000000        NaN        432.0  ...  14.100  42.310
# 118471          NaN   752.000000        NaN        679.0  ...  17.030  42.500
# 118472          NaN   321.000000        NaN        518.0  ...  19.970  42.700
# 118473          NaN   321.000000        NaN        429.0  ...  22.920  42.900
# 118474          NaN   321.000000        NaN        613.0  ...  25.900  43.120
# 118475          NaN   667.000000        NaN       1037.5  ...  28.890  43.215
# 118476          NaN   667.000000        NaN        465.5  ...  31.900  43.460
# 118477          NaN   513.000000        NaN        290.0  ...  41.650  43.990
# 118478          NaN  1052.000000        NaN        188.0  ...  43.760  44.470
# 118479          NaN   513.000000        NaN        131.0  ...  41.650  44.500
# 118480          NaN  1052.000000        NaN        539.0  ...  43.760  44.730
# 118481          NaN  1052.000000        NaN        215.0  ...  45.900  44.970
#
#         sound_D(km)  sound_ID  sound_hour     sumN_0.5  sumN_0.5_sumN_1.0  \
# 0               NaN       NaN         NaN   524.000000           1.000000
# 1               NaN       NaN         NaN  1482.000000           1.000000
# 2               NaN       NaN         NaN   991.000000           1.000000
# 3               NaN       NaN         NaN   363.000000           1.000000
# 4               NaN       NaN         NaN   592.666667           0.996667
# 5               NaN       NaN         NaN   452.500000           1.000000
# 6               NaN       NaN         NaN   171.000000           1.000000
# 7               NaN       NaN         NaN  1597.000000           1.000000
# 8               NaN       NaN         NaN  2717.500000           1.000000
# 9               NaN       NaN         NaN  1885.000000           1.000000
# 10              NaN       NaN         NaN   596.500000           1.000000
# 11              NaN       NaN         NaN   477.000000           0.980000
# 12              NaN       NaN         NaN   584.500000           1.000000
# 13              NaN       NaN         NaN   513.000000           0.890000
# 14              NaN       NaN         NaN  3658.000000           1.000000
# 15              NaN       NaN         NaN  1297.500000           1.000000
# 16              NaN       NaN         NaN   718.000000           1.000000
# 17              NaN       NaN         NaN  1652.000000           1.000000
# 18              NaN       NaN         NaN   891.000000           1.010000
# 19              NaN       NaN         NaN  3744.000000           0.880000
# 20              NaN       NaN         NaN  2223.500000           1.025000
# 21              NaN       NaN         NaN  2395.000000           0.985000
# 22              NaN       NaN         NaN  2861.000000           1.340000
# 23              NaN       NaN         NaN  2999.000000           0.975000
# 24              NaN       NaN         NaN  3058.000000           1.000000
# 25              NaN       NaN         NaN   788.000000           0.950000
# 26              NaN       NaN         NaN   296.000000           1.000000
# 27              NaN       NaN         NaN  2560.500000           0.975000
# 28              NaN       NaN         NaN  4444.500000           0.985000
# 29              NaN       NaN         NaN  3786.000000           1.000000
# ...             ...       ...         ...          ...                ...
# 118452          NaN       NaN         NaN   101.000000           1.000000
# 118453          NaN       NaN         NaN   324.000000           1.000000
# 118454          NaN       NaN         NaN  1058.000000           1.000000
# 118455          NaN       NaN         NaN   280.000000           1.000000
# 118456          NaN       NaN         NaN   885.000000           1.000000
# 118457          NaN       NaN         NaN    64.000000           1.000000
# 118458          NaN       NaN         NaN    72.000000           1.000000
# 118459          NaN       NaN         NaN   120.000000           1.000000
# 118460          NaN       NaN         NaN   731.000000           1.000000
# 118461          NaN       NaN         NaN   917.000000           1.000000
# 118462          NaN       NaN         NaN  1530.500000           1.000000
# 118463          NaN       NaN         NaN  1891.000000           1.000000
# 118464          NaN       NaN         NaN    52.000000           1.000000
# 118465          NaN       NaN         NaN   145.500000           1.000000
# 118466          NaN       NaN         NaN   192.000000           1.000000
# 118467          NaN       NaN         NaN   182.000000           0.990000
# 118468          NaN       NaN         NaN   123.000000           0.990000
# 118469          NaN       NaN         NaN   820.000000           1.000000
# 118470          NaN       NaN         NaN  1653.000000           1.000000
# 118471          NaN       NaN         NaN   546.000000           1.000000
# 118472          NaN       NaN         NaN   136.000000           1.000000
# 118473          NaN       NaN         NaN   209.000000           1.000000
# 118474          NaN       NaN         NaN   319.000000           1.000000
# 118475          NaN       NaN         NaN   106.000000           0.965000
# 118476          NaN       NaN         NaN   335.000000           1.000000
# 118477          NaN       NaN         NaN   799.000000           1.000000
# 118478          NaN       NaN         NaN    95.000000           1.000000
# 118479          NaN       NaN         NaN   208.000000           1.000000
# 118480          NaN       NaN         NaN    46.000000           1.000000
# 118481          NaN       NaN         NaN  2057.000000           1.000000
#
#            sumN_1.0         winNO                                  Coordinates
# 0        524.000000   1252.000000                    POINT (117.22395 25.9399)
# 1       1482.000000   1304.000000                     POINT (116.9385 26.2174)
# 2        991.000000   1206.000000                     POINT (117.3345 26.2847)
# 3        363.500000   1203.500000                   POINT (117.76445 26.19285)
# 4        594.666667   1170.333333  POINT (118.2538333333333 26.32436666666667)
# 5        452.500000   1102.500000                   POINT (118.74335 26.18495)
# 6        171.000000   1101.000000                     POINT (119.2955 26.2706)
# 7       1596.000000   2404.000000                    POINT (116.80505 26.6842)
# 8       2717.500000   2306.000000                    POINT (117.2027 26.75185)
# 9       1885.000000   1208.000000                       POINT (117.6345 26.66)
# 10       596.500000   1158.000000                   POINT (118.20235 26.75005)
# 11       491.500000   1106.500000                   POINT (118.80335 26.68225)
# 12       584.500000   1105.500000                    POINT (119.17235 26.7391)
# 13       577.000000   3507.000000                     POINT (116.5805 27.4615)
# 14      3659.000000   3304.500000                     POINT (118.26245 27.248)
# 15      1298.500000   3303.500000                    POINT (118.63535 27.3066)
# 16       718.000000   3301.000000                     POINT (119.0478 27.2076)
# 17      1652.000000    709.000000                     POINT (123.1648 27.4528)
# 18       880.000000    501.000000                     POINT (126.9995 27.2354)
# 19      4246.000000   5701.000000                     POINT (116.4893 27.7725)
# 20      2157.500000   4506.000000                    POINT (116.9365 27.68555)
# 21      2449.500000   4505.000000                   POINT (117.32835 27.75075)
# 22      2130.000000   5601.000000                     POINT (117.6693 27.9672)
# 23      3064.000000   3305.500000                   POINT (118.92305 27.67615)
# 24      3059.500000   3207.500000                    POINT (119.29525 27.7325)
# 25       833.000000   2903.000000                      POINT (123.0934 27.766)
# 26       296.000000   1805.000000                    POINT (123.6221 27.67045)
# 27      2602.000000   5705.500000                    POINT (116.3529 28.23875)
# 28      4533.500000   5607.500000                     POINT (116.7565 28.3078)
# 29      3777.000000   5605.000000                     POINT (117.1951 28.2178)
# ...             ...           ...                                          ...
# 118452   101.000000  42402.000000                     POINT (117.1894 48.5448)
# 118453   324.000000  42401.000000                      POINT (117.748 48.5903)
# 118454  1058.000000  42303.000000                     POINT (118.3415 48.6347)
# 118455   280.000000  42303.500000                   POINT (118.94045 48.83485)
# 118456   885.000000  42301.000000                     POINT (119.6562 48.7226)
# 118457    64.000000  45108.000000                     POINT (108.1903 49.0744)
# 118458    72.000000  45107.000000                     POINT (108.6884 49.1529)
# 118459   120.000000  45009.000000                     POINT (109.1878 49.2292)
# 118460   731.000000  45008.000000                     POINT (109.6907 49.3035)
# 118461   918.000000  45005.500000                    POINT (110.2617 49.22255)
# 118462  1530.500000  44907.500000           POINT (110.7773 49.29565000000001)
# 118463  1891.000000  44905.000000                     POINT (111.3647 49.2114)
# 118464    52.000000  44805.000000                     POINT (113.0439 49.4178)
# 118465   145.500000  44802.500000          POINT (113.70165 49.33105000000001)
# 118466   192.000000  44703.000000                      POINT (114.387 49.2427)
# 118467   184.000000  42409.000000                     POINT (116.4903 49.1245)
# 118468   124.000000  42408.000000                     POINT (117.0251 49.1694)
# 118469   820.000000  42304.000000                      POINT (119.5914 49.035)
# 118470  1653.000000  44908.000000                     POINT (111.2458 49.5206)
# 118471   546.000000  44907.000000                       POINT (111.7905 49.59)
# 118472   136.000000  44809.000000                     POINT (112.3528 49.6585)
# 118473   209.000000  44808.000000                     POINT (112.9358 49.7286)
# 118474   319.000000  44807.000000                      POINT (113.5458 49.797)
# 118475   108.000000  44707.500000                   POINT (114.23775 49.70935)
# 118476   335.000000  44706.500000          POINT (114.91435 49.77889999999999)
# 118477   799.000000  44601.000000                     POINT (117.5125 49.5264)
# 118478    95.000000  44506.000000                      POINT (118.042 49.8834)
# 118479   208.000000  44607.000000                     POINT (117.3525 50.1501)
# 118480    46.000000  44509.000000                     POINT (117.9664 50.1954)
# 118481  2062.000000  44508.000000                      POINT (118.623 50.2395)
#
# [118482 rows x 157 columns]

# %%
cities_with_country = gpd.sjoin(mapfile,gdf,how="inner", op='intersects')

# %%
cities_with_country=cities_with_country.drop(["geometry"],axis=1)

# %%
cities_with_country.to_csv("jjj_ccn_new.csv")

# %%
df=pd.read_csv("jjj_ccn_new.csv")

# %%
df=df.drop(["Unnamed: 0"],axis=1)

# %%
df["Date"]=pd.to_datetime(df["BJC"].str.slice(stop=10),format="%Y-%m-%d")

# %%
avg_data=df.groupby(['Date']).mean()

# %%
avg_data.to_csv("jjj_ccn_avg_new.csv")

# %%
df=avg_data.dropna(subset=['CCN_1.0_cm3'])
df_2 =df[2<=df['WSPD850']]
#df =df[df['WSPD850']<2]
df_wind0=df_2[270<df_2['WDIR850']]
df_wind0=df_wind0[df_wind0['WDIR850']<=360]
print(df_wind0['CCN_1.0_cm3'].mean())
df_wind0["rih"]=df_wind0['H14_1.0']-df_wind0['Hcbs1.0']
print(df_wind0['rih'].mean())

# %%
df_2 =df[2<=df['WSPD850']]
#df =df[df['WSPD850']<2]
df_wind0=df_2[0<df_2['WDIR850']]
df_wind0=df_wind0[df_wind0['WDIR850']<=90]
print(df_wind0['CCN_1.0_cm3'].mean())
df_wind0["rih"]=df_wind0['H14_1.0']-df_wind0['Hcbs1.0']
print(df_wind0['rih'].mean())

# %%
df_2 =df[2<=df['WSPD850']]
#df =df[df['WSPD850']<2]
df_wind0=df_2[90<df_2['WDIR850']]
df_wind0=df_wind0[df_wind0['WDIR850']<=180]
print(df_wind0['CCN_1.0_cm3'].mean())
df_wind0["rih"]=df_wind0['H14_1.0']-df_wind0['Hcbs1.0']
print(df_wind0['rih'].mean())

# %%
df_2 =df[2<=df['WSPD850']]
#df =df[df['WSPD850']<2]
df_wind0=df_2[180<df_2['WDIR850']]
df_wind0=df_wind0[df_wind0['WDIR850']<=270]
print(df_wind0['CCN_1.0_cm3'].mean())
df_wind0["rih"]=df_wind0['H14_1.0']-df_wind0['Hcbs1.0']
print(df_wind0['rih'].mean())
