# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# y = 86.608ln(x) + 560.83
#
# R^2=0.9675

# %%
def get_pmcb(ps,p,pms):
    pm=np.exp((p-ps)/86.608)*pms
    return pm

# %%
df=pd.read_csv("yrd/yrd_ccn_new-all.csv")

# %%
pms=df["PM25"]

# %%
p=df["Pcb1.0"]

# %%
ps=df["Press"]

# %%
df["PM25cb"]=get_pmcb(ps,p,pms)

# %%
x = np.arange(0.0, len(p), 1)

# %%
plt.plot(x,df["PM25cb"])

# %%
plt.plot(x,df["PM25"])

# %%
df.to_csv("yrd/yrd_ccn_new-all-pmcb.csv")
